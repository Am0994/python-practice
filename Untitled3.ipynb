# %% [markdown]
# <a href="https://colab.research.google.com/github/Am0994/python-practice/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Type Casting

# %%
a=int(5)
print(a)
# Out:
# 5

# %%
#Type data

# %%
x=5
print(type(x))
# Out:
# <class 'int'>

# %%
#Type numbers

# %%
#lists

# %%
a = [1, 2, 3, 4, 5]

b = ['apple', 'banana', 'cherry']
c = [1, 'hello', 3.14, True]

print(a)
print(b)
print(c)
# Out:
# [1, 2, 3, 4, 5]
# ['apple', 'banana', 'cherry']
# [1, 'hello', 3.14, True]

# %%
a = list((1, 2, 3, 'apple', 4.5))
print(a)

b = list("GFG")
print(b)
# Out:
# [1, 2, 3, 'apple', 4.5]
# ['G', 'F', 'G']

# %%
a = [2] * 5
b = [0] * 7

print(a)
print(b)
# Out:
# [2, 2, 2, 2, 2]
# [0, 0, 0, 0, 0, 0, 0]

# %% [markdown]
# list.

# %%
nameList = ['Harsh', 'Pratik', 'Bob', 'Dhruv']

pos = nameList.index("Harsh")

print (pos * 3)
# Out:
# 0

# %%
li = [1, 3, 5, 7, 9]
print(li.pop(-3), end = ' ')
# Out:
# 5

# %% [markdown]
# #operators in python
#
# 1.   List item
# 2.   List item

# %%
a = 10
b = a
print(b)
b += a
print(b)
b -= a
print(b)
b *= a
print(b)
b <<= a
print(b)
# Out:
# 10
# 20
# 10
# 100
# 102400

# %% [markdown]
# #identity operator

# %%
a=10
b=20
c=a
print(a is not b)
print(a is c)
# Out:
# True
# True

# %% [markdown]
# #strings

# %%
s=""" I am learning python string on Geeks for Geeks"""


print(s)
s='''I' am
Geeks'''
print(s)
# Out:
#  I am learning python string on Geeks for Geeks
# I' am
# Geeks

# %%
s = "GeeksforGeeks"
print(s[-10])   # 3rd character
print(s[-5])    # 5th character from end
# Out:
# k
# G

# %% [markdown]
# strings

# %%
a=("hello,world")
print(a.upper())
# Out:
# HELLO,WORLD

# %% [markdown]
# #remove whitespace

# %%
a="Hello,World!"
print(a.strip())
# Out:
# Hello,World!

# %%
#replace string

# %%
a="Hello,World!"
print(a.replace("H" ,"J"))
# Out:
# Jello,World!

# %% [markdown]
# #
